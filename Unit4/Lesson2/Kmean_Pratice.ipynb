# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
# %matplotlib inline

# %% [markdown]
# ### Code from Course Material

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/master/cleveland.csv", header=None, error_bad_lines=False)

# Define the features and the outcome.
X = df.iloc[:, :13]
y = df.iloc[:, 13]

# Replace missing values (marked by ?) with a 0.
X = X.replace(to_replace='?', value=0)

# Binarize y so that 1 means heart disease diagnosis and 0 means no diagnosis.
y_1 = np.where(y > 0, 0, 1)

# %%
# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(2).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=2, random_state=42).fit_predict(X_pca)

# Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y_1))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      84  65
# 1      55  99

# %%
# Each batch will be made up of 200 data points.
minibatchkmeans = MiniBatchKMeans(
    init='random',
    n_clusters=2,
    batch_size=200)
minibatchkmeans.fit(X_pca)

# Add the new predicted cluster memberships to the data frame.
predict_mini = minibatchkmeans.predict(X_pca)

# Check the MiniBatch model against our earlier one.
print('Comparing k-means and mini batch k-means solutions:')
print(pd.crosstab(predict_mini, y_pred))
# Out:
# Comparing k-means and mini batch k-means solutions:
# col_0    0    1
# row_0
# 0      122    0
# 1       27  154

# %% [markdown]
# ### Different K value

# %%
y_pred_2 = KMeans(n_clusters=3, random_state=42).fit_predict(X_pca)

# %%
y_2 = np.where(y > 1, 2, y)

# Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred_2)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred_2, y_2))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1   2
# row_0
# 0      70  30  35
# 1      61  10  15
# 2      33  15  34

# %%
y_pred_3 = KMeans(n_clusters=4, random_state=42).fit_predict(X_pca)

y_3 = np.where(y > 2, 3, y)

# Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred_3)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred_3, y_3))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1   2   3
# row_0
# 0      21  11  14  15
# 1      67  20   9   8
# 2      20  15   8  19
# 3      56   9   5   6

# %%
y_pred_4 = KMeans(n_clusters=5, random_state=42).fit_predict(X_pca)


# Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred_4, y))
# Out:
# Comparing k-means clusters against the data:
# 13      0   1   2   3  4
# row_0
# 0      21   5   5   3  2
# 1      12   9  13  11  3
# 2      58   7   2   3  2
# 3      45  18   8   7  1
# 4      28  16   8  11  5

# %%
# Each batch will be made up of 200 data points.
minibatchkmeans = MiniBatchKMeans(
    init='random',
    n_clusters=2,
    batch_size=200)
minibatchkmeans.fit(X_pca)

# Add the new predicted cluster memberships to the data frame.
predict_mini = minibatchkmeans.predict(X_pca)

# Check the MiniBatch model against our earlier one.
print('Comparing k-means and mini batch k-means solutions:')
print(pd.crosstab(predict_mini, y_pred))
# Out:
# Comparing k-means and mini batch k-means solutions:
# col_0    0    1
# row_0
# 0      149    0
# 1        0  154

# %%
# Each batch will be made up of 200 data points.
minibatchkmeans = MiniBatchKMeans(
    init='random',
    n_clusters=3,
    batch_size=200)
minibatchkmeans.fit(X_pca)

# Add the new predicted cluster memberships to the data frame.
predict_mini_2 = minibatchkmeans.predict(X_pca)

# Check the MiniBatch model against our earlier one.
print('Comparing k-means and mini batch k-means solutions:')
print(pd.crosstab(predict_mini_2, y_pred_2))
# Out:
# Comparing k-means and mini batch k-means solutions:
# col_0   0   1   2
# row_0
# 0      47  61   0
# 1      41   0  82
# 2      47  25   0

# %%
# Each batch will be made up of 200 data points.
minibatchkmeans = MiniBatchKMeans(
    init='random',
    n_clusters=4,
    batch_size=200)
minibatchkmeans.fit(X_pca)

# Add the new predicted cluster memberships to the data frame.
predict_mini_3 = minibatchkmeans.predict(X_pca)

# Check the MiniBatch model against our earlier one.
print('Comparing k-means and mini batch k-means solutions:')
print(pd.crosstab(predict_mini_3, y_pred_3))
# Out:
# Comparing k-means and mini batch k-means solutions:
# col_0   0   1   2   3
# row_0
# 0      52  11   0   0
# 1       0  92  11  11
# 2       9   1  37   0
# 3       0   0  14  65

# %%
# Each batch will be made up of 200 data points.
minibatchkmeans = MiniBatchKMeans(
    init='random',
    n_clusters=5,
    batch_size=200)
minibatchkmeans.fit(X_pca)

# Add the new predicted cluster memberships to the data frame.
predict_mini_4 = minibatchkmeans.predict(X_pca)

# Check the MiniBatch model against our earlier one.
print('Comparing k-means and mini batch k-means solutions:')
print(pd.crosstab(predict_mini_4, y_pred_4))
# Out:
# Comparing k-means and mini batch k-means solutions:
# col_0   0   1   2   3   4
# row_0
# 0       0   0  65  12   0
# 1       0   9   0  48   0
# 2      36   0   7   0  12
# 3       0   0   0  19  56
# 4       0  39   0   0   0
