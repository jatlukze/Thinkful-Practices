# %% [markdown]
# ### This is the assignment for Gradient boosting. In this assignment, we will utilize the course example and modify it. The purpose of this assignment is to find out how changing of hyper parameters will change model performance. The first part of this assignment will be reusing some codes from the course material.

# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv((
    "https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/"
    "master/ESS_practice_data/ESSdata_Thinkful.csv")).dropna()

# Definine outcome and predictors.
# Set our outcome to 0 and 1.
y = df['partner'] - 1
X = df.loc[:, ~df.columns.isin(['partner', 'cntry', 'idno'])]

# Make the categorical variable 'country' into dummies.
X = pd.concat([X, pd.get_dummies(df['cntry'])], axis=1)

# Create training and test sets.
offset = int(X.shape[0] * 0.9)

# Put 90% of the data in the training set.
X_train, y_train = X[:offset], y[:offset]

# And put 10% in the test set.
X_test, y_test = X[offset:], y[offset:]

# %%
# We'll make 500 iterations, use 2-deep trees, and set our loss function.
params = {'n_estimators': 500,
          'max_depth': 2,
          'loss': 'deviance'}

# Initialize and fit the model.
clf = ensemble.GradientBoostingClassifier(**params)
clf.fit(X_train, y_train)

predict_train = clf.predict(X_train)
predict_test = clf.predict(X_test)

# Accuracy tables.
table_train = pd.crosstab(y_train, predict_train, margins=True)
table_test = pd.crosstab(y_test, predict_test, margins=True)

train_tI_errors = table_train.loc[0.0,1.0] / table_train.loc['All','All']
train_tII_errors = table_train.loc[1.0,0.0] / table_train.loc['All','All']

test_tI_errors = table_test.loc[0.0,1.0]/table_test.loc['All','All']
test_tII_errors = table_test.loc[1.0,0.0]/table_test.loc['All','All']

print((
    'Training set accuracy:\n'
    'Percent Type I errors: {}\n'
    'Percent Type II errors: {}\n\n'
    'Test set accuracy:\n'
    'Percent Type I errors: {}\n'
    'Percent Type II errors: {}'
).format(train_tI_errors, train_tII_errors, test_tI_errors, test_tII_errors))
# Out:
# Training set accuracy:
# Percent Type I errors: 0.04650845608292417
# Percent Type II errors: 0.17607746863066012
#
# Test set accuracy:
# Percent Type I errors: 0.06257668711656442
# Percent Type II errors: 0.18527607361963191

# %% [markdown]
# ### Above code is from course material. Starting from below, we will try changing the n_estimater, max_deepth, and different loss function to see if they will help increase model performance.

# %%
# We'll make 1000 iterations, use 2-deep trees, and set our loss function.
params1 = {'n_estimators': 1000,
          'max_depth': 2,
          'loss': 'deviance'}

# Initialize and fit the model.
clf_EstChanged = ensemble.GradientBoostingClassifier(**params1)
clf_EstChanged.fit(X_train, y_train)

predict_train_1 = clf_EstChanged.predict(X_train)
predict_test_1 = clf_EstChanged.predict(X_test)

# Accuracy tables.
table_train_1 = pd.crosstab(y_train, predict_train_1, margins=True)
table_test_1 = pd.crosstab(y_test, predict_test_1, margins=True)

train_tI_errors_1 = table_train_1.loc[0.0,1.0] / table_train_1.loc['All','All']
train_tII_errors_1 = table_train_1.loc[1.0,0.0] / table_train_1.loc['All','All']

test_tI_errors_1 = table_test_1.loc[0.0,1.0]/table_test_1.loc['All','All']
test_tII_errors_1 = table_test_1.loc[1.0,0.0]/table_test_1.loc['All','All']

print((
    'Training set accuracy with Changed n_estimators:\n'
    'Percent Type I errors: {}\n'
    'Percent Type II errors: {}\n\n'
    'Test set accuracy with Changed n_estimators:\n'
    'Percent Type I errors: {}\n'
    'Percent Type II errors: {}\n\n'
).format(train_tI_errors_1, train_tII_errors_1, test_tI_errors_1, test_tII_errors_1))

# We'll make 500 iterations, use 4-deep trees, and set our loss function.
params2 = {'n_estimators': 500,
          'max_depth': 4,
          'loss': 'deviance'}

# Initialize and fit the model.
clf_depth = ensemble.GradientBoostingClassifier(**params2)
clf_depth.fit(X_train, y_train)

predict_train_2 = clf_depth.predict(X_train)
predict_test_2 = clf_depth.predict(X_test)

# Accuracy tables.
table_train_2 = pd.crosstab(y_train, predict_train_2, margins=True)
table_test_2 = pd.crosstab(y_test, predict_test_2, margins=True)

train_tI_errors_2 = table_train_2.loc[0.0,1.0] / table_train_2.loc['All','All']
train_tII_errors_2 = table_train_2.loc[1.0,0.0] / table_train_2.loc['All','All']

test_tI_errors_2 = table_test_2.loc[0.0,1.0]/table_test_2.loc['All','All']
test_tII_errors_2 = table_test_2.loc[1.0,0.0]/table_test_2.loc['All','All']

print((
    'Training set accuracy with Change of Max Depth:\n'
    'Percent Type I errors: {}\n'
    'Percent Type II errors: {}\n\n'
    'Test set accuracy with Changed of Max Depth:\n'
    'Percent Type I errors: {}\n'
    'Percent Type II errors: {}\n\n'
).format(train_tI_errors_2, train_tII_errors_2, test_tI_errors_2, test_tII_errors_2))

# We'll make 500 iterations, use 2-deep trees, and set our loss function.
params3 = {'n_estimators': 500,
          'max_depth': 2,
          'loss': 'exponential'}

# Initialize and fit the model.
clf_loss = ensemble.GradientBoostingClassifier(**params3)
clf_loss.fit(X_train, y_train)

predict_train_3 = clf_loss.predict(X_train)
predict_test_3 = clf_loss.predict(X_test)

# Accuracy tables.
table_train_3 = pd.crosstab(y_train, predict_train_3, margins=True)
table_test_3 = pd.crosstab(y_test, predict_test_3, margins=True)

train_tI_errors_3 = table_train_3.loc[0.0,1.0] / table_train_3.loc['All','All']
train_tII_errors_3 = table_train_3.loc[1.0,0.0] / table_train_3.loc['All','All']

test_tI_errors_3 = table_test_3.loc[0.0,1.0]/table_test_3.loc['All','All']
test_tII_errors_3 = table_test_3.loc[1.0,0.0]/table_test_3.loc['All','All']

print((
    'Training set accuracy with changed of loss function:\n'
    'Percent Type I errors: {}\n'
    'Percent Type II errors: {}\n\n'
    'Test set accuracy with changed of loss function:\n'
    'Percent Type I errors: {}\n'
    'Percent Type II errors: {}'
).format(train_tI_errors_3, train_tII_errors_3, test_tI_errors_3, test_tII_errors_3))
# Out:
# Training set accuracy with Changed n_estimators:
# Percent Type I errors: 0.044189852700491
# Percent Type II errors: 0.1692580469176214
#
# Test set accuracy with Changed n_estimators:
# Percent Type I errors: 0.07116564417177915
# Percent Type II errors: 0.18036809815950922
#
#
# Training set accuracy with Change of Max Depth:
# Percent Type I errors: 0.01950354609929078
# Percent Type II errors: 0.11824877250409166
#
# Test set accuracy with Changed of Max Depth:
# Percent Type I errors: 0.08588957055214724
# Percent Type II errors: 0.18036809815950922
#
#
# Training set accuracy with changed of loss function:
# Percent Type I errors: 0.04841789416257501
# Percent Type II errors: 0.1778505182760502
#
# Test set accuracy with changed of loss function:
# Percent Type I errors: 0.0638036809815951
# Percent Type II errors: 0.18773006134969325

# %% [markdown]
# ### According to above model performance, we can see that increasing the n-estimater, tree depth, and change of loss function tend to help increase accuracy on the training data set. However, the performance on the testing data set is decreasing, which is a sign of overfitting. Next, we will try GridSeachCV and see if we can fine tune our hyper-parameters.

# %%
from sklearn.model_selection import GridSearchCV
clf_n = {'n_estimators':np.arange(100,1000,100)}

clf_n_grid_search = GridSearchCV(clf, clf_n, cv=5, scoring="balanced_accuracy")
clf_n_grid_search.fit(X_train, y_train)

print(('Best number of n_estimator is: {}').format(clf_n_grid_search.best_params_))
# Out:
# Best number of n_estimator is: {'n_estimators': 800}

# %%
params4 = {'n_estimators': 800,
          'max_depth': 1,
          'loss': 'deviance'}

clf_4 = ensemble.GradientBoostingClassifier(**params4)
clf_4.fit(X_train, y_train)

clf_depth = {'max_depth':np.arange(1,10,1)}

clf_depth_grid_search = GridSearchCV(clf_4, clf_depth, cv=5, scoring="balanced_accuracy")
clf_depth_grid_search.fit(X_train, y_train)

print(('Best number of max depth is: {}').format(clf_depth_grid_search.best_params_))
# Out:
# Best number of max depth is: {'max_depth': 1}

# %%
params5 = {'n_estimators': 800,
          'max_depth': 1,
          'subsample': 0.2,
          'loss': 'deviance'}

clf_5 = ensemble.GradientBoostingClassifier(**params5)
clf_5.fit(X_train, y_train)

clf_subsample = {'subsample':np.arange(0.1,1,0.1)}

clf_subsample_grid_search = GridSearchCV(clf_5, clf_subsample, cv=5, scoring="balanced_accuracy")
clf_subsample_grid_search.fit(X_train, y_train)

print(('Best number of subsample is: {}').format(clf_subsample_grid_search.best_params_))
# Out:
# Best number of subsample is: {'subsample': 0.1}

# %%
params6 = {'n_estimators': 800,
          'max_depth': 1,
          'loss': 'deviance',
          'subsample': 0.3}

# Initialize and fit the model.
clf_CV = ensemble.GradientBoostingClassifier(**params6)
clf_CV.fit(X_train, y_train)

predict_train_6 = clf_CV.predict(X_train)
predict_test_6 = clf_CV.predict(X_test)

# Accuracy tables.
table_train_6 = pd.crosstab(y_train, predict_train_6, margins=True)
table_test_6 = pd.crosstab(y_test, predict_test_6, margins=True)

train_tI_errors_6 = table_train_6.loc[0.0,1.0] / table_train_6.loc['All','All']
train_tII_errors_6 = table_train_6.loc[1.0,0.0] / table_train_6.loc['All','All']

test_tI_errors_6 = table_test_6.loc[0.0,1.0]/table_test_6.loc['All','All']
test_tII_errors_6 = table_test_6.loc[1.0,0.0]/table_test_6.loc['All','All']

print((
    'Training set accuracy with tuned parameters:\n'
    'Percent Type I errors: {}\n'
    'Percent Type II errors: {}\n\n'
    'Test set accuracy with tuned parameters:\n'
    'Percent Type I errors: {}\n'
    'Percent Type II errors: {}'
).format(train_tI_errors_6, train_tII_errors_6, test_tI_errors_6, test_tII_errors_6))
# Out:
# Training set accuracy with tuned parameters:
# Percent Type I errors: 0.05360065466448445
# Percent Type II errors: 0.19148936170212766
#
# Test set accuracy with tuned parameters:
# Percent Type I errors: 0.05889570552147239
# Percent Type II errors: 0.20122699386503068

# %% [markdown]
# ### After fine tunning our hyper-parameters, we see an increase of performace on our training data set, as well as increase of performance on our testing data set, because the Type I error on the testing data set actually decreased. However, the Type II error on our testing data set increased.

# %%
clf_para = {'n_estimators':np.arange(100,1000,100),
        'max_depth':np.arange(1,10,1),
        'subsample':np.arange(0.1,1,0.1)}

clf_grid_search = GridSearchCV(clf, clf_para, cv=5, scoring="balanced_accuracy", verbose=10)
clf_grid_search.fit(X_train, y_train)

print(('Best parameter is: {}').format(clf_grid_search.best_params_))
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# [CV] max_depth=1, n_estimators=100, subsample=0.1 ....................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=1, n_estimators=100, subsample=0.1, score=0.6989786708003846, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.1 ....................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  max_depth=1, n_estimators=100, subsample=0.1, score=0.6621087848046623, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.1 ....................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV]  max_depth=1, n_estimators=100, subsample=0.1, score=0.710861801699272, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.1 ....................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s remaining:    0.0s
# [CV]  max_depth=1, n_estimators=100, subsample=0.1, score=0.6854684568768232, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.1 ....................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.9s remaining:    0.0s
# [CV]  max_depth=1, n_estimators=100, subsample=0.1, score=0.698052203619304, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.2 ....................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.1s remaining:    0.0s
# [CV]  max_depth=1, n_estimators=100, subsample=0.2, score=0.7138963561799737, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.2 ....................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    1.4s remaining:    0.0s
# [CV]  max_depth=1, n_estimators=100, subsample=0.2, score=0.6408296214901007, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.2 ....................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    1.6s remaining:    0.0s
# [CV]  max_depth=1, n_estimators=100, subsample=0.2, score=0.7003787061201263, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.2 ....................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    1.9s remaining:    0.0s
# [CV]  max_depth=1, n_estimators=100, subsample=0.2, score=0.6794986887725536, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.2 ....................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    2.1s remaining:    0.0s
# [CV]  max_depth=1, n_estimators=100, subsample=0.2, score=0.6998459158854229, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=100, subsample=0.30000000000000004, score=0.7136726644820752, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=100, subsample=0.30000000000000004, score=0.6068206345780272, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=100, subsample=0.30000000000000004, score=0.7101132193944627, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=100, subsample=0.30000000000000004, score=0.6750886429041478, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=100, subsample=0.30000000000000004, score=0.6934100014955802, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.4, score=0.7019641700841788, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.4, score=0.6017444028020329, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.4, score=0.7023723093224497, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.4, score=0.6778486047950655, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.4, score=0.6960695759636653, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.5, score=0.6959931715165905, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.5, score=0.5836263563761945, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.5, score=0.7028196927182466, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.5, score=0.675523754333926, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.5, score=0.6928619500791083, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.6, score=0.6937758766163687, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.6, score=0.6109442144300767, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.6, score=0.703821399839099, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.6, score=0.673318731399723, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.6, score=0.6959613431884195, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=100, subsample=0.7000000000000001, score=0.7018474187155388, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=100, subsample=0.7000000000000001, score=0.5819633852010282, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=100, subsample=0.7000000000000001, score=0.6988422973529815, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=100, subsample=0.7000000000000001, score=0.6750886429041478, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=100, subsample=0.7000000000000001, score=0.6919754252564133, total=   0.3s
# [CV] max_depth=1, n_estimators=100, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.8, score=0.6952151560936366, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.8, score=0.5805241057237603, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.8, score=0.6968585051900398, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.8, score=0.6764234429787945, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.8, score=0.691643839390433, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.9, score=0.6952151560936366, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.9, score=0.5819633852010282, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.9, score=0.6933186821811903, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.9, score=0.6725536031744472, total=   0.2s
# [CV] max_depth=1, n_estimators=100, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=100, subsample=0.9, score=0.6892076180130824, total=   0.2s
# [CV] max_depth=1, n_estimators=200, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.1, score=0.7144408688656476, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.1, score=0.629490022172949, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.1, score=0.7047544296842807, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.1, score=0.6882284187677409, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.1, score=0.7026068355885108, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.2, score=0.6967711869395444, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.2, score=0.5912701371583305, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.2, score=0.7078664913760964, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.2, score=0.6788239222889022, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.2, score=0.7068161066112515, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=200, subsample=0.30000000000000004, score=0.6739958401193022, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=200, subsample=0.30000000000000004, score=0.5823911465180621, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=200, subsample=0.30000000000000004, score=0.7115230657535859, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=200, subsample=0.30000000000000004, score=0.6799338002023317, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=200, subsample=0.30000000000000004, score=0.7061598224195338, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.4, score=0.6739958401193022, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.4, score=0.5782871887447756, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.4, score=0.7126317132036968, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.4, score=0.6876882127036823, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.4, score=0.7084809234813958, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.5, score=0.6722259286148774, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.5, score=0.5651874889625808, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.5, score=0.7093057708533642, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.5, score=0.680383644524766, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.5, score=0.7078177517494353, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.6, score=0.6657006063222338, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.6, score=0.5731717128112552, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.6, score=0.707428919019681, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.6, score=0.6812686002769783, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.6, score=0.7039400665926748, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=200, subsample=0.7000000000000001, score=0.6674705178266586, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=200, subsample=0.7000000000000001, score=0.5599748837391834, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=200, subsample=0.7000000000000001, score=0.7096560249592843, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=200, subsample=0.7000000000000001, score=0.6828283225128422, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=200, subsample=0.7000000000000001, score=0.7061598224195338, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.8, score=0.668355473578871, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.8, score=0.5605292074642387, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.8, score=0.7067774660047486, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.8, score=0.6799485330949879, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.8, score=0.7044950055493895, total=   0.5s
# [CV] max_depth=1, n_estimators=200, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.9, score=0.6600602397818025, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.9, score=0.559089927986971, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.9, score=0.7097727763279242, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.9, score=0.6810584110084175, total=   0.4s
# [CV] max_depth=1, n_estimators=200, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=200, subsample=0.9, score=0.7020587841720389, total=   0.4s
# [CV] max_depth=1, n_estimators=300, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.1, score=0.6722259286148774, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.1, score=0.6261444577438533, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.1, score=0.7043168573278653, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.1, score=0.6866834294245332, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.1, score=0.7144563566092836, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.2, score=0.700311009948394, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.2, score=0.5971440064360418, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.2, score=0.7050850617114377, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.2, score=0.6809238505888247, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.2, score=0.7094756810793366, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=300, subsample=0.30000000000000004, score=0.6701253850832958, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=300, subsample=0.30000000000000004, score=0.5844916900496439, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=300, subsample=0.30000000000000004, score=0.708090183073995, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=300, subsample=0.30000000000000004, score=0.6805034720517027, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=300, subsample=0.30000000000000004, score=0.7073710455679663, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.4, score=0.6609451955340149, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.4, score=0.5777230539803386, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.4, score=0.7075260483095579, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.4, score=0.6810436781157612, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.4, score=0.7059295817885565, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.5, score=0.6535349174891588, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.5, score=0.567181092164904, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.5, score=0.7078566803367149, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.5, score=0.6841483896948327, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.5, score=0.7069312269267403, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.6, score=0.6535349174891588, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.6, score=0.5607528991621372, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.6, score=0.7118536977807429, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.6, score=0.6806085666859831, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.6, score=0.7081493376154155, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=300, subsample=0.7000000000000001, score=0.6517650059847341, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=300, subsample=0.7000000000000001, score=0.5634077664187744, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=300, subsample=0.7000000000000001, score=0.710958930989149, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=300, subsample=0.7000000000000001, score=0.6809385834814807, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=300, subsample=0.7000000000000001, score=0.7069312269267403, total=   0.8s
# [CV] max_depth=1, n_estimators=300, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.8, score=0.6487795067009399, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.8, score=0.5594205600141279, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.8, score=0.7145085650373801, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.8, score=0.6828283225128422, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.8, score=0.7071545800174747, total=   0.7s
# [CV] max_depth=1, n_estimators=300, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.9, score=0.6466789631693581, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.9, score=0.5594205600141279, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.9, score=0.7068745952946256, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.9, score=0.6794986887725536, total=   0.6s
# [CV] max_depth=1, n_estimators=300, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=300, subsample=0.9, score=0.7062680551947795, total=   0.6s
# [CV] max_depth=1, n_estimators=400, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.1, score=0.7046190373408159, total=   0.7s
# [CV] max_depth=1, n_estimators=400, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.1, score=0.6056344799168023, total=   0.7s
# [CV] max_depth=1, n_estimators=400, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.1, score=0.695263230186606, total=   0.7s
# [CV] max_depth=1, n_estimators=400, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.1, score=0.6894433913154508, total=   0.7s
# [CV] max_depth=1, n_estimators=400, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.1, score=0.7053746428318417, total=   0.7s
# [CV] max_depth=1, n_estimators=400, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.2, score=0.6805211624119459, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.2, score=0.6172262229460589, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.2, score=0.7111826226870475, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.2, score=0.6815986170724759, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.2, score=0.7109171448587464, total=   0.8s
# [CV] max_depth=1, n_estimators=400, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=400, subsample=0.30000000000000004, score=0.6630457390655966, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=400, subsample=0.30000000000000004, score=0.5960255479465495, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=400, subsample=0.30000000000000004, score=0.7041127877087299, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=400, subsample=0.30000000000000004, score=0.682813589620186, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=400, subsample=0.30000000000000004, score=0.707479278343212, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.4, score=0.6665855620744462, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.4, score=0.5752820673822185, total=   1.1s
# [CV] max_depth=1, n_estimators=400, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.4, score=0.7097531542491612, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.4, score=0.6811635056426979, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.4, score=0.7069312269267403, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.5, score=0.6544198732413712, total=   1.1s
# [CV] max_depth=1, n_estimators=400, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.5, score=0.566850460137747, total=   1.1s
# [CV] max_depth=1, n_estimators=400, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.5, score=0.7072052273217825, total=   1.1s
# [CV] max_depth=1, n_estimators=400, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.5, score=0.6810436781157612, total=   1.1s
# [CV] max_depth=1, n_estimators=400, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.5, score=0.70837269070615, total=   1.1s
# [CV] max_depth=1, n_estimators=400, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.6, score=0.6491101387280969, total=   1.1s
# [CV] max_depth=1, n_estimators=400, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.6, score=0.5648470458960422, total=   1.1s
# [CV] max_depth=1, n_estimators=400, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.6, score=0.706981535623884, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.6, score=0.6827084949859055, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.6, score=0.7075943986587008, total=   1.1s
# [CV] max_depth=1, n_estimators=400, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=400, subsample=0.7000000000000001, score=0.6475639189215705, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=400, subsample=0.7000000000000001, score=0.559089927986971, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=400, subsample=0.7000000000000001, score=0.7049879324215607, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=400, subsample=0.7000000000000001, score=0.6818235392336931, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=400, subsample=0.7000000000000001, score=0.7090358624381106, total=   1.0s
# [CV] max_depth=1, n_estimators=400, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.8, score=0.6422541844082963, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.8, score=0.5611904715185527, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.8, score=0.7081971234032534, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.8, score=0.680383644524766, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.8, score=0.7081493376154155, total=   0.9s
# [CV] max_depth=1, n_estimators=400, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.9, score=0.6325196711339599, total=   0.8s
# [CV] max_depth=1, n_estimators=400, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.9, score=0.5603055157663404, total=   0.8s
# [CV] max_depth=1, n_estimators=400, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.9, score=0.7112993740556874, total=   0.8s
# [CV] max_depth=1, n_estimators=400, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.9, score=0.6841483896948327, total=   0.8s
# [CV] max_depth=1, n_estimators=400, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=400, subsample=0.9, score=0.706152934879291, total=   0.8s
# [CV] max_depth=1, n_estimators=500, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.1, score=0.7002040696191354, total=   0.9s
# [CV] max_depth=1, n_estimators=500, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.1, score=0.6453417185016581, total=   0.9s
# [CV] max_depth=1, n_estimators=500, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.1, score=0.7110560602790259, total=   0.9s
# [CV] max_depth=1, n_estimators=500, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.1, score=0.6854684568768232, total=   0.9s
# [CV] max_depth=1, n_estimators=500, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.1, score=0.7120201352319331, total=   0.9s
# [CV] max_depth=1, n_estimators=500, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.2, score=0.6736652080921453, total=   1.1s
# [CV] max_depth=1, n_estimators=500, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.2, score=0.5945764574299002, total=   1.1s
# [CV] max_depth=1, n_estimators=500, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.2, score=0.70620352020093, total=   1.1s
# [CV] max_depth=1, n_estimators=500, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.2, score=0.6880034966065237, total=   1.1s
# [CV] max_depth=1, n_estimators=500, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.2, score=0.7054828756070874, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=500, subsample=0.30000000000000004, score=0.6704560171104527, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=500, subsample=0.30000000000000004, score=0.579172144496988, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=500, subsample=0.30000000000000004, score=0.7007868453583972, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=500, subsample=0.30000000000000004, score=0.6852435347156061, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=500, subsample=0.30000000000000004, score=0.7084809234813958, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.4, score=0.6710103408355081, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.4, score=0.5685134313129133, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.4, score=0.7048809920923023, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.4, score=0.6827084949859055, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.4, score=0.7096990341700711, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.5, score=0.6565204167729529, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.5, score=0.5651874889625808, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.5, score=0.702556756862822, total=   1.4s
# [CV] max_depth=1, n_estimators=500, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.5, score=0.6800536277292684, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.5, score=0.7091440952133563, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.6, score=0.6422541844082963, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.6, score=0.5637383984459313, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.6, score=0.7045503600651453, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.6, score=0.6839234675336155, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.6, score=0.7077026314339465, total=   1.3s
# [CV] max_depth=1, n_estimators=500, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=500, subsample=0.7000000000000001, score=0.6478945509487275, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=500, subsample=0.7000000000000001, score=0.5640690304730883, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=500, subsample=0.7000000000000001, score=0.7107450503306321, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=500, subsample=0.7000000000000001, score=0.6815986170724759, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=500, subsample=0.7000000000000001, score=0.7116954369061956, total=   1.2s
# [CV] max_depth=1, n_estimators=500, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.8, score=0.6395993171516591, total=   1.1s
# [CV] max_depth=1, n_estimators=500, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.8, score=0.5617447952436081, total=   1.1s
# [CV] max_depth=1, n_estimators=500, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.8, score=0.7036555932735514, total=   1.1s
# [CV] max_depth=1, n_estimators=500, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.8, score=0.6788386551815584, total=   1.1s
# [CV] max_depth=1, n_estimators=500, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.8, score=0.7108089120835006, total=   1.1s
# [CV] max_depth=1, n_estimators=500, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.9, score=0.6342895826383848, total=   1.0s
# [CV] max_depth=1, n_estimators=500, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.9, score=0.5611904715185527, total=   1.0s
# [CV] max_depth=1, n_estimators=500, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.9, score=0.7044336086965053, total=   1.0s
# [CV] max_depth=1, n_estimators=500, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.9, score=0.6855882844037599, total=   1.1s
# [CV] max_depth=1, n_estimators=500, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=500, subsample=0.9, score=0.7089276296628647, total=   1.0s
# [CV] max_depth=1, n_estimators=600, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.1, score=0.6710103408355081, total=   1.1s
# [CV] max_depth=1, n_estimators=600, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.1, score=0.6114691050369876, total=   1.1s
# [CV] max_depth=1, n_estimators=600, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.1, score=0.7027412044031944, total=   1.1s
# [CV] max_depth=1, n_estimators=600, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.1, score=0.6832487010499642, total=   1.1s
# [CV] max_depth=1, n_estimators=600, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.1, score=0.7087042765721303, total=   1.1s
# [CV] max_depth=1, n_estimators=600, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.2, score=0.6924631595471225, total=   1.3s
# [CV] max_depth=1, n_estimators=600, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.2, score=0.5942556364421246, total=   1.3s
# [CV] max_depth=1, n_estimators=600, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.2, score=0.7056295743971117, total=   1.3s
# [CV] max_depth=1, n_estimators=600, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.2, score=0.6847936903931717, total=   1.3s
# [CV] max_depth=1, n_estimators=600, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.2, score=0.706592753520517, total=   1.3s
# [CV] max_depth=1, n_estimators=600, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=600, subsample=0.30000000000000004, score=0.6630457390655966, total=   1.4s
# [CV] max_depth=1, n_estimators=600, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=600, subsample=0.30000000000000004, score=0.5776063026116987, total=   1.4s
# [CV] max_depth=1, n_estimators=600, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=600, subsample=0.30000000000000004, score=0.6977915350352216, total=   1.4s
# [CV] max_depth=1, n_estimators=600, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=600, subsample=0.30000000000000004, score=0.6848084232858279, total=   1.4s
# [CV] max_depth=1, n_estimators=600, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=600, subsample=0.30000000000000004, score=0.7068229941514943, total=   1.4s
# [CV] max_depth=1, n_estimators=600, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.4, score=0.6556354610207406, total=   1.7s
# [CV] max_depth=1, n_estimators=600, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.4, score=0.5690677550379687, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.4, score=0.7059896395424131, total=   1.5s
# [CV] max_depth=1, n_estimators=600, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.4, score=0.6842534843291131, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.4 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.4, score=0.7102539731267858, total=   1.5s
# [CV] max_depth=1, n_estimators=600, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.5, score=0.6517650059847341, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.5, score=0.5645164138688853, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.5, score=0.7056393854364931, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.5, score=0.686023395833538, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.5 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.5, score=0.7075943986587008, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.6, score=0.6511037419304201, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.6, score=0.5656250613189961, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.6, score=0.7058728881737731, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.6, score=0.6830385117814032, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.6 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.6, score=0.707039459701986, total=   1.6s
# [CV] max_depth=1, n_estimators=600, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=600, subsample=0.7000000000000001, score=0.6457940074171458, total=   1.5s
# [CV] max_depth=1, n_estimators=600, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=600, subsample=0.7000000000000001, score=0.5622991189686636, total=   1.5s
# [CV] max_depth=1, n_estimators=600, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=600, subsample=0.7000000000000001, score=0.7020024331377666, total=   1.5s
# [CV] max_depth=1, n_estimators=600, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=600, subsample=0.7000000000000001, score=0.6829334171471226, total=   1.5s
# [CV] max_depth=1, n_estimators=600, subsample=0.7000000000000001 .....
# [CV]  max_depth=1, n_estimators=600, subsample=0.7000000000000001, score=0.7043798852339009, total=   1.5s
# [CV] max_depth=1, n_estimators=600, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.8, score=0.6395993171516591, total=   1.3s
# [CV] max_depth=1, n_estimators=600, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.8, score=0.5626297509958205, total=   1.4s
# [CV] max_depth=1, n_estimators=600, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.8, score=0.7087514471283087, total=   1.3s
# [CV] max_depth=1, n_estimators=600, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.8, score=0.683818372899335, total=   1.4s
# [CV] max_depth=1, n_estimators=600, subsample=0.8 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.8, score=0.7064845207452712, total=   1.4s
# [CV] max_depth=1, n_estimators=600, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.9, score=0.6289798481251103, total=   1.2s
# [CV] max_depth=1, n_estimators=600, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.9, score=0.5620754272707651, total=   1.2s
# [CV] max_depth=1, n_estimators=600, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.9, score=0.7081971234032534, total=   1.2s
# [CV] max_depth=1, n_estimators=600, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.9, score=0.6868032569514698, total=   1.2s
# [CV] max_depth=1, n_estimators=600, subsample=0.9 ....................
# [CV]  max_depth=1, n_estimators=600, subsample=0.9, score=0.7089276296628647, total=   1.2s
# [CV] max_depth=1, n_estimators=700, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=700, subsample=0.1, score=0.6370513902242804, total=   1.3s
# [CV] max_depth=1, n_estimators=700, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=700, subsample=0.1, score=0.6118291701822891, total=   1.3s
# [CV] max_depth=1, n_estimators=700, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=700, subsample=0.1, score=0.7004562133312403, total=   1.3s
# [CV] max_depth=1, n_estimators=700, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=700, subsample=0.1, score=0.6764990718277627, total=   1.3s
# [CV] max_depth=1, n_estimators=700, subsample=0.1 ....................
# [CV]  max_depth=1, n_estimators=700, subsample=0.1, score=0.7049348241906157, total=   1.3s
# [CV] max_depth=1, n_estimators=700, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=700, subsample=0.2, score=0.6905863077134391, total=   1.5s
# [CV] max_depth=1, n_estimators=700, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=700, subsample=0.2, score=0.5818270117536252, total=   1.5s
# [CV] max_depth=1, n_estimators=700, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=700, subsample=0.2, score=0.7056491964758747, total=   1.5s
# [CV] max_depth=1, n_estimators=700, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=700, subsample=0.2, score=0.6821388231365346, total=   1.6s
# [CV] max_depth=1, n_estimators=700, subsample=0.2 ....................
# [CV]  max_depth=1, n_estimators=700, subsample=0.2, score=0.711133610409238, total=   1.5s
# [CV] max_depth=1, n_estimators=700, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=700, subsample=0.30000000000000004, score=0.6704560171104527, total=   1.7s
# [CV] max_depth=1, n_estimators=700, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=700, subsample=0.30000000000000004, score=0.5867089849498656, total=   1.7s
# [CV] max_depth=1, n_estimators=700, subsample=0.30000000000000004 ....
# [CV]  max_depth=1, n_estimators=700, subsample=0.30000000000000004, score=0.7055422561466161, total=   1.7s
# ...
# [CV] max_depth=9, n_estimators=700, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=700, subsample=0.9, score=0.5444616682691364, total=  16.7s
# [CV] max_depth=9, n_estimators=700, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=700, subsample=0.9, score=0.5589633655789494, total=  16.0s
# [CV] max_depth=9, n_estimators=700, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=700, subsample=0.9, score=0.705911151227361, total=  16.8s
# [CV] max_depth=9, n_estimators=700, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=700, subsample=0.9, score=0.6911691041419072, total=  16.5s
# [CV] max_depth=9, n_estimators=700, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=700, subsample=0.9, score=0.6885838036539385, total=  16.3s
# [CV] max_depth=9, n_estimators=800, subsample=0.1 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.1, score=0.5457518199478053, total=   9.4s
# [CV] max_depth=9, n_estimators=800, subsample=0.1 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.1, score=0.5639748444950258, total=   8.8s
# [CV] max_depth=9, n_estimators=800, subsample=0.1 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.1, score=0.5698781468908816, total=   9.5s
# [CV] max_depth=9, n_estimators=800, subsample=0.1 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.1, score=0.6097885338807421, total=   8.7s
# [CV] max_depth=9, n_estimators=800, subsample=0.1 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.1, score=0.5964570492990452, total=   9.5s
# [CV] max_depth=9, n_estimators=800, subsample=0.2 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.2, score=0.6621509722740027, total=  15.4s
# [CV] max_depth=9, n_estimators=800, subsample=0.2 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.2, score=0.6366579675450817, total=  15.3s
# [CV] max_depth=9, n_estimators=800, subsample=0.2 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.2, score=0.5637903969546534, total=  12.3s
# [CV] max_depth=9, n_estimators=800, subsample=0.2 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.2, score=0.6694361230884072, total=  15.2s
# [CV] max_depth=9, n_estimators=800, subsample=0.2 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.2, score=0.5517923347580702, total=  11.2s
# [CV] max_depth=9, n_estimators=800, subsample=0.30000000000000004 ....
# [CV]  max_depth=9, n_estimators=800, subsample=0.30000000000000004, score=0.6505003630084571, total=  20.1s
# [CV] max_depth=9, n_estimators=800, subsample=0.30000000000000004 ....
# [CV]  max_depth=9, n_estimators=800, subsample=0.30000000000000004, score=0.6370955399014973, total=  18.2s
# [CV] max_depth=9, n_estimators=800, subsample=0.30000000000000004 ....
# [CV]  max_depth=9, n_estimators=800, subsample=0.30000000000000004, score=0.6962737672429018, total=  18.4s
# [CV] max_depth=9, n_estimators=800, subsample=0.30000000000000004 ....
# [CV]  max_depth=9, n_estimators=800, subsample=0.30000000000000004, score=0.686714859595533, total=  18.4s
# [CV] max_depth=9, n_estimators=800, subsample=0.30000000000000004 ....
# [CV]  max_depth=9, n_estimators=800, subsample=0.30000000000000004, score=0.6937947198148628, total=  19.4s
# [CV] max_depth=9, n_estimators=800, subsample=0.4 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.4, score=0.6482830681082354, total=  20.0s
# [CV] max_depth=9, n_estimators=800, subsample=0.4 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.4, score=0.6303170927928105, total=  19.0s
# [CV] max_depth=9, n_estimators=800, subsample=0.4 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.4, score=0.6981506190765849, total=  20.0s
# [CV] max_depth=9, n_estimators=800, subsample=0.4 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.4, score=0.6781953188689067, total=  19.8s
# [CV] max_depth=9, n_estimators=800, subsample=0.4 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.4, score=0.6813627096764037, total=  19.4s
# [CV] max_depth=9, n_estimators=800, subsample=0.5 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.5, score=0.5882326393658144, total=  18.8s
# [CV] max_depth=9, n_estimators=800, subsample=0.5 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.5, score=0.6214086690343975, total=  17.9s
# [CV] max_depth=9, n_estimators=800, subsample=0.5 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.5, score=0.7087798991425152, total=  18.8s
# [CV] max_depth=9, n_estimators=800, subsample=0.5 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.5, score=0.6814051250822587, total=  18.6s
# [CV] max_depth=9, n_estimators=800, subsample=0.5 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.5, score=0.6836975858187515, total=  18.2s
# [CV] max_depth=9, n_estimators=800, subsample=0.6 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.6, score=0.5941163196829072, total=  19.1s
# [CV] max_depth=9, n_estimators=800, subsample=0.6 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.6, score=0.5893255891529149, total=  17.3s
# [CV] max_depth=9, n_estimators=800, subsample=0.6 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.6, score=0.6992690775660774, total=  17.8s
# [CV] max_depth=9, n_estimators=800, subsample=0.6 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.6, score=0.6907192598194729, total=  17.7s
# [CV] max_depth=9, n_estimators=800, subsample=0.6 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.6, score=0.7027613132768161, total=  17.5s
# [CV] max_depth=9, n_estimators=800, subsample=0.7000000000000001 .....
# [CV]  max_depth=9, n_estimators=800, subsample=0.7000000000000001, score=0.5542933108333497, total=  17.3s
# [CV] max_depth=9, n_estimators=800, subsample=0.7000000000000001 .....
# [CV]  max_depth=9, n_estimators=800, subsample=0.7000000000000001, score=0.5853864568412378, total=  16.5s
# [CV] max_depth=9, n_estimators=800, subsample=0.7000000000000001 .....
# [CV]  max_depth=9, n_estimators=800, subsample=0.7000000000000001, score=0.7084590781547397, total=  17.3s
# [CV] max_depth=9, n_estimators=800, subsample=0.7000000000000001 .....
# [CV]  max_depth=9, n_estimators=800, subsample=0.7000000000000001, score=0.6902841483896949, total=  17.0s
# [CV] max_depth=9, n_estimators=800, subsample=0.7000000000000001 .....
# [CV]  max_depth=9, n_estimators=800, subsample=0.7000000000000001, score=0.6876903912910005, total=  16.7s
# [CV] max_depth=9, n_estimators=800, subsample=0.8 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.8, score=0.544568608598395, total=  17.0s
# [CV] max_depth=9, n_estimators=800, subsample=0.8 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.8, score=0.563184074720876, total=  16.0s
# [CV] max_depth=9, n_estimators=800, subsample=0.8 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.8, score=0.7001442222789083, total=  17.1s
# [CV] max_depth=9, n_estimators=800, subsample=0.8 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.8, score=0.6949338493119739, total=  16.7s
# [CV] max_depth=9, n_estimators=800, subsample=0.8 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.8, score=0.6912433781220235, total=  16.3s
# [CV] max_depth=9, n_estimators=800, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.9, score=0.5380432863057512, total=  17.0s
# [CV] max_depth=9, n_estimators=800, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.9, score=0.558739673881051, total=  16.1s
# [CV] max_depth=9, n_estimators=800, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.9, score=0.701466750387536, total=  16.8s
# [CV] max_depth=9, n_estimators=800, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.9, score=0.6923988095822734, total=  16.6s
# [CV] max_depth=9, n_estimators=800, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=800, subsample=0.9, score=0.679373194480522, total=  16.5s
# [CV] max_depth=9, n_estimators=900, subsample=0.1 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.1, score=0.5528599179797107, total=  10.3s
# [CV] max_depth=9, n_estimators=900, subsample=0.1 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.1, score=0.5960765653513334, total=  10.6s
# [CV] max_depth=9, n_estimators=900, subsample=0.1 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.1, score=0.5789229440966976, total=   9.6s
# [CV] max_depth=9, n_estimators=900, subsample=0.1 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.1, score=0.5338836887234439, total=  11.4s
# [CV] max_depth=9, n_estimators=900, subsample=0.1 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.1, score=0.5423701797057643, total=  10.3s
# [CV] max_depth=9, n_estimators=900, subsample=0.2 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.2, score=0.6488864470301984, total=  16.7s
# [CV] max_depth=9, n_estimators=900, subsample=0.2 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.2, score=0.6190461707513294, total=  17.0s
# [CV] max_depth=9, n_estimators=900, subsample=0.2 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.2, score=0.6932784569197261, total=  17.4s
# [CV] max_depth=9, n_estimators=900, subsample=0.2 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.2, score=0.5593755217899482, total=  15.0s
# [CV] max_depth=9, n_estimators=900, subsample=0.2 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.2, score=0.66870734644721, total=  14.1s
# [CV] max_depth=9, n_estimators=900, subsample=0.30000000000000004 ....
# [CV]  max_depth=9, n_estimators=900, subsample=0.30000000000000004, score=0.6286394050585719, total=  20.1s
# [CV] max_depth=9, n_estimators=900, subsample=0.30000000000000004 ....
# [CV]  max_depth=9, n_estimators=900, subsample=0.30000000000000004, score=0.6284206188803642, total=  19.8s
# [CV] max_depth=9, n_estimators=900, subsample=0.30000000000000004 ....
# [CV]  max_depth=9, n_estimators=900, subsample=0.30000000000000004, score=0.6952622490826679, total=  20.1s
# [CV] max_depth=9, n_estimators=900, subsample=0.30000000000000004 ....
# [CV]  max_depth=9, n_estimators=900, subsample=0.30000000000000004, score=0.6865194032196281, total=  20.9s
# [CV] max_depth=9, n_estimators=900, subsample=0.30000000000000004 ....
# [CV]  max_depth=9, n_estimators=900, subsample=0.30000000000000004, score=0.6820052187876355, total=  20.0s
# [CV] max_depth=9, n_estimators=900, subsample=0.4 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.4, score=0.6387624354924161, total=  20.0s
# [CV] max_depth=9, n_estimators=900, subsample=0.4 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.4, score=0.625979632282244, total=  19.3s
# [CV] max_depth=9, n_estimators=900, subsample=0.4 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.4, score=0.7099954869218845, total=  20.2s
# [CV] max_depth=9, n_estimators=900, subsample=0.4 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.4, score=0.6850647756180448, total=  20.0s
# [CV] max_depth=9, n_estimators=900, subsample=0.4 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.4, score=0.6930095402271708, total=  19.7s
# [CV] max_depth=9, n_estimators=900, subsample=0.5 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.5, score=0.6257216019465102, total=  18.9s
# [CV] max_depth=9, n_estimators=900, subsample=0.5 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.5, score=0.6323783921668662, total=  18.3s
# [CV] max_depth=9, n_estimators=900, subsample=0.5 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.5, score=0.7029158409041854, total=  18.9s
# [CV] max_depth=9, n_estimators=900, subsample=0.5 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.5, score=0.6926089988508344, total=  18.7s
# [CV] max_depth=9, n_estimators=900, subsample=0.5 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.5, score=0.6891249675301674, total=  18.3s
# [CV] max_depth=9, n_estimators=900, subsample=0.6 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.6, score=0.587795067009399, total=  18.0s
# [CV] max_depth=9, n_estimators=900, subsample=0.6 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.6, score=0.5958509114455586, total=  17.3s
# [CV] max_depth=9, n_estimators=900, subsample=0.6 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.6, score=0.7071071169279673, total=  18.1s
# [CV] max_depth=9, n_estimators=900, subsample=0.6 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.6, score=0.684299647392769, total=  17.8s
# [CV] max_depth=9, n_estimators=900, subsample=0.6 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.6, score=0.6898963720373738, total=  17.6s
# [CV] max_depth=9, n_estimators=900, subsample=0.7000000000000001 .....
# [CV]  max_depth=9, n_estimators=900, subsample=0.7000000000000001, score=0.5769715283637149, total=  17.4s
# [CV] max_depth=9, n_estimators=900, subsample=0.7000000000000001 .....
# [CV]  max_depth=9, n_estimators=900, subsample=0.7000000000000001, score=0.5858240291976532, total=  16.9s
# [CV] max_depth=9, n_estimators=900, subsample=0.7000000000000001 .....
# [CV]  max_depth=9, n_estimators=900, subsample=0.7000000000000001, score=0.7030325922728253, total=  17.4s
# [CV] max_depth=9, n_estimators=900, subsample=0.7000000000000001 .....
# [CV]  max_depth=9, n_estimators=900, subsample=0.7000000000000001, score=0.6867443253808453, total=  17.3s
# [CV] max_depth=9, n_estimators=900, subsample=0.7000000000000001 .....
# [CV]  max_depth=9, n_estimators=900, subsample=0.7000000000000001, score=0.7085340559346982, total=  16.9s
# [CV] max_depth=9, n_estimators=900, subsample=0.8 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.8, score=0.5400368895080745, total=  17.1s
# [CV] max_depth=9, n_estimators=900, subsample=0.8 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.8, score=0.562853442693719, total=  16.1s
# [CV] max_depth=9, n_estimators=900, subsample=0.8 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.8, score=0.70247826854777, total=  17.0s
# [CV] max_depth=9, n_estimators=900, subsample=0.8 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.8, score=0.69373360965692, total=  16.8s
# [CV] max_depth=9, n_estimators=900, subsample=0.8 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.8, score=0.6984438094788297, total=  16.7s
# [CV] max_depth=9, n_estimators=900, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.9, score=0.5379363459764928, total=  16.9s
# [CV] max_depth=9, n_estimators=900, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.9, score=0.5639522791044483, total=  16.1s
# [CV] max_depth=9, n_estimators=900, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.9, score=0.7076810627317858, total=  17.0s
# [CV] max_depth=9, n_estimators=900, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.9, score=0.6909441819806901, total=  16.9s
# [CV] max_depth=9, n_estimators=900, subsample=0.9 ....................
# [CV]  max_depth=9, n_estimators=900, subsample=0.9, score=0.7002099715839768, total=  16.6s
# [Parallel(n_jobs=1)]: Done 3645 out of 3645 | elapsed: 323.9min finished
# Best parameter is: {'max_depth': 2, 'n_estimators': 100, 'subsample': 0.1}
